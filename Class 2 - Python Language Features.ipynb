# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# First Program in python

print("Hello World")
# Out:
# Hello World

# %%
print("Welcome to analytics Sakha")
# Out:
# Welcome to analytics Sakha

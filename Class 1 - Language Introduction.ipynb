# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Hellow World
# ## Hello World
# ### Hello World
# #### Helllo World

# %% [markdown]
# Language - > Language is a structured system of communication
#
# Structure -> Grammer
# Free components -> Vocabulary

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Assembly Language eg -> ADD A, B

# %% [markdown]
# ![image.png](attachment:image.png)
